# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka29-code/ML117/blob/main/session2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello");
# Out:
# hello
